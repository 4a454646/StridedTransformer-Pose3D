# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
tf.keras.backend.clear_session()
from tensorflow.keras.layers import Input, Softmax, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
import numpy as np
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from tensorflow.keras import models, layers, optimizers, regularizers, initializers
import matplotlib.pyplot as plt
import random
from IPython.display import clear_output
import pickle

# %%
BATCH_SIZE = 256
SEED = 23582068
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
t = np.load("/home/jeff/Documents/Code/EvoSkeleton-master/examples/daniel_kpts_normalized/daniel_test_kpts_3D_40_good.npy")
print(t)
t = np.load("/home/jeff/Documents/Code/EvoSkeleton-master/examples/daniel_test_3d_kpts/daniel_test_kpts_3D_40_good.npy")
print(t["arr_0"])
# Out:
# [[ 0.5         0.5         0.5       ]
#  [ 0.59799673  0.43253659  0.29712528]
#  [ 0.60647529  0.33060896  0.06604592]
#  [ 0.5591551   0.26663983 -0.02819525]
#  [ 0.60647529  0.33060896  0.06604592]
#  [ 0.74297747  0.2529259   0.14551239]
#  [ 0.6309764   0.20065895  0.4367079 ]
#  [ 0.60647529  0.33060896  0.06604592]
#  [ 0.53200832  0.463728    0.05759885]
#  [ 0.41452575  0.68684333  0.19937916]]
# [[   0.            0.            0.        ]
#  [  97.99673202  -67.46341412 -202.87471721]
#  [ 106.4752863  -169.39104459 -433.9540833 ]
#  [  59.15510187 -233.36017221 -528.19525244]
#  [ 106.4752863  -169.39104459 -433.9540833 ]
#  [ 242.97746781 -247.07410178 -354.48760971]
#  [ 130.97639959 -299.3410506   -63.29209611]
#  [ 106.4752863  -169.39104459 -433.9540833 ]
#  [  32.00832326  -36.27199515 -442.4011478 ]
#  [ -85.47424741  186.84333448 -300.62083579]]

# %%
dataset_path = "/home/jeff/Documents/Code/EvoSkeleton-master/examples/keypoints_normalized/"
jeff_val = "/home/jeff/Documents/Code/EvoSkeleton-master/examples/jeff_kpts_normalized/"
daniel_test = "/home/jeff/Documents/Code/EvoSkeleton-master/examples/daniel_kpts_normalized/"
val_datapath = daniel_test
test_datapath = jeff_val

partition = {
    "train": [],
    "val": [],
    "test": [],
}
labels = {}
classes = []
val_classes = []
good = 0 
ok = 0
bad = 0
test = False
for f in os.listdir(dataset_path):
    rand = random.random()
    # if (rand < 0.05):
        # test = True
        # partition["test"].append(f)
    # elif (rand > 0.1 and rand < 0.3):
    #     test = False
    #     partition["val"].append(f)
    # else:
        # test = False
    partition["train"].append(f)
    if ("ok") in f:
        labels[f] = 1
        ok += 1
    elif ("good") in f:
        labels[f] = 0
        good += 1
    elif ("bad") in f:
        labels[f] = 1
        bad += 1

for f in os.listdir(val_datapath):
    partition["val"].append(f)
    if ("ok") in f:
        labels[f] = 1
        # ok += 1
        val_classes.append(1)
    elif ("good") in f:
        labels[f] = 0
        # good += 1
        val_classes.append(0)
    elif ("bad") in f:
        labels[f] = 1
        # bad += 1
        val_classes.append(1)
    else:
        print("something went wrong!")

    # label is not being added because you haven't labelled test set with good, bad, ok, yet


for f in os.listdir(test_datapath):
    # print(f)
    partition["test"].append(f)
    if ("ok") in f:
        labels[f] = 1
        classes.append(1)
    elif ("good") in f:
        labels[f] = 0
        classes.append(0)
    elif ("bad") in f:
        labels[f] = 1
        classes.append(1)
print(good)
print(ok)
print(bad)
print(len(partition["train"]))
print(len(partition["val"]))
print(len(val_classes))
print(len(partition["test"]))
print(len(classes))
# print(len(labels))
# labels

# labels = to_categorical(labels)
# print(partition["test"])
labels
# Out:
# 47258
# 48745
# 47499
# 143502
# 559
# 559
# 697
# 697
# {'eddie_good0_scaled_kpts_3D_1989.npy': 0,
#  'chris_ok_scaled_kpts_3D_486.npy': 1,
#  'michael_ok_scaled_kpts_3D_513.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1629.npy': 1,
#  'connor_bad_scaled_kpts_3D_3073.npy': 1,
#  'amruthok1_scaled_kpts_3D_929.npy': 1,
#  'chris_buff_3d_8177_ok.npy': 1,
#  'isaac_bad_scaled_kpts_3D_627.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_3131.npy': 0,
#  'daniel_bad_scaled_kpts_3D_1915.npy': 1,
#  'isaac_ok_scaled_kpts_3D_4093.npy': 1,
#  'connor_good_scaled_kpts_3D_599.npy': 0,
#  'connor_good_scaled_kpts_3D_603.npy': 0,
#  'isaac_ok_scaled_kpts_3D_3289.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_3808.npy': 0,
#  'michael_bad_scaled_kpts_3D_1550.npy': 1,
#  'chris_ok_scaled_kpts_3D_1182.npy': 1,
#  'michael_ok_scaled_kpts_3D_1199.npy': 1,
#  'amruthgood1_scaled_kpts_3D_1673.npy': 0,
#  'connor_bad_scaled_kpts_3D_771.npy': 1,
#  'connor_bad_scaled_kpts_3D_2474.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3390.npy': 0,
#  'eddie_ok_scaled_kpts_3D_759.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_3431.npy': 1,
#  'chris_good0_scaled_kpts_3D_1596.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_1639.npy': 1,
#  'isaac_ok_scaled_kpts_3D_3234.npy': 1,
#  'isaac_ok_scaled_kpts_3D_1277.npy': 1,
#  'daniel_ok_scaled_kpts_3D_1500.npy': 1,
#  'isaac_ok_scaled_kpts_3D_76.npy': 1,
#  'amruthok1_scaled_kpts_3D_23.npy': 1,
#  'connor_bad_scaled_kpts_3D_1296.npy': 1,
#  'connor_bad_scaled_kpts_3D_3021.npy': 1,
#  'amruth_bad1_3D_3822.npy': 1,
#  'chris_bad0_scaled_kpts_3D_2431.npy': 1,
#  'michael_good_scaled_kpts_3D_1617.npy': 0,
#  'amruthgood2_scaled_kpts_3D_3031.npy': 0,
#  'michael_good_scaled_kpts_3D_2845.npy': 0,
#  'connor_ok_scaled_kpts_3D_1408.npy': 1,
#  'chris_buff_3d_3016_ok.npy': 1,
#  'chris_good0_scaled_kpts_3D_4450.npy': 0,
#  'chris_bad1_scaled_kpts_3D_3627.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_422.npy': 0,
#  'isaac_ok_scaled_kpts_3D_4498.npy': 1,
#  'chris_ok_scaled_kpts_3D_3479.npy': 1,
#  'daniel_good_scaled_kpts_3D_281.npy': 0,
#  'daniel_bad_scaled_kpts_3D_3046.npy': 1,
#  'chris_buff_3d_9680_ok.npy': 1,
#  'daniel_ok_scaled_kpts_3D_2488.npy': 1,
#  'chris_buff_3d_5225_ok.npy': 1,
#  'chris_buff_3d_1622_ok.npy': 1,
#  'michael_bad_scaled_kpts_3D_2728.npy': 1,
#  'eddie_good0_scaled_kpts_3D_4334.npy': 0,
#  'daniel_bad_scaled_kpts_3D_3254.npy': 1,
#  'chris_bad1_scaled_kpts_3D_1367.npy': 1,
#  'connor_bad_scaled_kpts_3D_1681.npy': 1,
#  'amruthgood2_scaled_kpts_3D_113.npy': 0,
#  'michael_good_scaled_kpts_3D_580.npy': 0,
#  'amruthok1_scaled_kpts_3D_2069.npy': 1,
#  'michael_bad_scaled_kpts_3D_3107.npy': 1,
#  'daniel_ok_scaled_kpts_3D_2650.npy': 1,
#  'michael_bad_scaled_kpts_3D_2552.npy': 1,
#  'amruthok1_scaled_kpts_3D_4018.npy': 1,
#  'isaac_ok_scaled_kpts_3D_965.npy': 1,
#  'amruthgood1_scaled_kpts_3D_82.npy': 0,
#  'amruth_bad1_3D_2572.npy': 1,
#  'michael_bad_scaled_kpts_3D_305.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_1027.npy': 0,
#  'connor_bad_scaled_kpts_3D_20.npy': 1,
#  'chris_buff_3d_7350_ok.npy': 1,
#  'isaac_bad_scaled_kpts_3D_2749.npy': 1,
#  'amruthok1_scaled_kpts_3D_3793.npy': 1,
#  'amruthgood2_scaled_kpts_3D_2843.npy': 0,
#  'eddie_good0_scaled_kpts_3D_4021.npy': 0,
#  'chris_buff_3d_1312_ok.npy': 1,
#  'chris_ok_scaled_kpts_3D_2283.npy': 1,
#  'michael_bad_scaled_kpts_3D_497.npy': 1,
#  'daniel_good_scaled_kpts_3D_3111.npy': 0,
#  'eddie_good1_scaled_kpts_3D_3032.npy': 0,
#  'amruthok2_scaled_kpts_3D_3066.npy': 1,
#  'chris_good1_scaled_kpts_3D_1953.npy': 0,
#  'amruthok2_scaled_kpts_3D_2364.npy': 1,
#  'amruthok1_scaled_kpts_3D_3358.npy': 1,
#  'isaac_ok_scaled_kpts_3D_1215.npy': 1,
#  'chris_good1_scaled_kpts_3D_2510.npy': 0,
#  'chris_bad0_scaled_kpts_3D_1492.npy': 1,
#  'eddie_good0_scaled_kpts_3D_3205.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_1747.npy': 0,
#  'chris_bad0_scaled_kpts_3D_1355.npy': 1,
#  'michael_ok_scaled_kpts_3D_2039.npy': 1,
#  'eddie_ok_scaled_kpts_3D_1943.npy': 1,
#  'daniel_ok_scaled_kpts_3D_982.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_2318.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3632.npy': 0,
#  'amruthok1_scaled_kpts_3D_3083.npy': 1,
#  'eddie_good1_scaled_kpts_3D_4061.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_856.npy': 1,
#  'michael_good_scaled_kpts_3D_2238.npy': 0,
#  'chris_good0_scaled_kpts_3D_3935.npy': 0,
#  'michael_bad_scaled_kpts_3D_2420.npy': 1,
#  'michael_good_scaled_kpts_3D_3354.npy': 0,
#  'michael_ok_scaled_kpts_3D_2538.npy': 1,
#  'amruthok1_scaled_kpts_3D_3327.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1432.npy': 1,
#  'chris_ok_scaled_kpts_3D_1836.npy': 1,
#  'amruthok2_scaled_kpts_3D_400.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_3351.npy': 1,
#  'chris_buff_3d_1236_ok.npy': 1,
#  'daniel_good_scaled_kpts_3D_1276.npy': 0,
#  'isaac_ok_scaled_kpts_3D_1570.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_1614.npy': 1,
#  'amruthok1_scaled_kpts_3D_1358.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_3444.npy': 1,
#  'eddie_good1_scaled_kpts_3D_3910.npy': 0,
#  'chris_ok_scaled_kpts_3D_4263.npy': 1,
#  'chris_good0_scaled_kpts_3D_1490.npy': 0,
#  'connor_ok_scaled_kpts_3D_3240.npy': 1,
#  'eddie_ok_scaled_kpts_3D_180.npy': 1,
#  'chris_bad1_scaled_kpts_3D_641.npy': 1,
#  'daniel_good_scaled_kpts_3D_2550.npy': 0,
#  'michael_good_scaled_kpts_3D_2051.npy': 0,
#  'connor_bad_scaled_kpts_3D_2883.npy': 1,
#  'eddie_good1_scaled_kpts_3D_4064.npy': 0,
#  'daniel_good_scaled_kpts_3D_210.npy': 0,
#  'amruthok2_scaled_kpts_3D_2328.npy': 1,
#  'michael_good_scaled_kpts_3D_3124.npy': 0,
#  'eddie_good1_scaled_kpts_3D_3156.npy': 0,
#  'chris_bad0_scaled_kpts_3D_1998.npy': 1,
#  'eddie_ok_scaled_kpts_3D_457.npy': 1,
#  'amruthgood2_scaled_kpts_3D_1486.npy': 0,
#  'chris_good1_scaled_kpts_3D_687.npy': 0,
#  'daniel_bad_scaled_kpts_3D_682.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_3416.npy': 1,
#  'chris_good1_scaled_kpts_3D_1003.npy': 0,
#  'isaac_ok_scaled_kpts_3D_2200.npy': 1,
#  'eddie_ok_scaled_kpts_3D_240.npy': 1,
#  'isaac_good_scaled_kpts_3D_1195.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_3510.npy': 1,
#  'michael_bad_scaled_kpts_3D_323.npy': 1,
#  'amruthbad2_scaled_kpts_3D_1772.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3049.npy': 0,
#  'isaac_good_scaled_kpts_3D_467.npy': 0,
#  'amruthbad2_scaled_kpts_3D_2230.npy': 1,
#  'michael_good_scaled_kpts_3D_3015.npy': 0,
#  'amruthgood1_scaled_kpts_3D_4071.npy': 0,
#  'chris_ok_scaled_kpts_3D_3975.npy': 1,
#  'amruthok1_scaled_kpts_3D_3760.npy': 1,
#  'eddie_good1_scaled_kpts_3D_168.npy': 0,
#  'isaac_ok_scaled_kpts_3D_316.npy': 1,
#  'michael_bad_scaled_kpts_3D_1948.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_3139.npy': 1,
#  'daniel_bad_scaled_kpts_3D_409.npy': 1,
#  'connor_ok_scaled_kpts_3D_3272.npy': 1,
#  'connor_bad_scaled_kpts_3D_2666.npy': 1,
#  'chris_buff_3d_6764_ok.npy': 1,
#  'daniel_good_scaled_kpts_3D_2714.npy': 0,
#  'chris_good0_scaled_kpts_3D_688.npy': 0,
#  'chris_bad0_scaled_kpts_3D_184.npy': 1,
#  'isaac_good_scaled_kpts_3D_1373.npy': 0,
#  'isaac_ok_2_scaled_kpts_3D_3865.npy': 1,
#  'michael_bad_scaled_kpts_3D_2938.npy': 1,
#  'eddie_good0_scaled_kpts_3D_380.npy': 0,
#  'eddie_good1_scaled_kpts_3D_2199.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_2488.npy': 0,
#  'chris_good1_scaled_kpts_3D_3378.npy': 0,
#  'eddie_good0_scaled_kpts_3D_638.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_2345.npy': 1,
#  'connor_ok_scaled_kpts_3D_357.npy': 1,
#  'eddie_good1_scaled_kpts_3D_3264.npy': 0,
#  'eddie_good1_scaled_kpts_3D_2476.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_2494.npy': 1,
#  'chris_bad1_scaled_kpts_3D_1423.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_3738.npy': 1,
#  'amruthgood1_scaled_kpts_3D_787.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_2988.npy': 1,
#  'chris_buff_3d_1117_ok.npy': 1,
#  'chris_ok_scaled_kpts_3D_604.npy': 1,
#  'amruthok2_scaled_kpts_3D_1561.npy': 1,
#  'amruthok2_scaled_kpts_3D_751.npy': 1,
#  'chris_good1_scaled_kpts_3D_3128.npy': 0,
#  'chris_good0_scaled_kpts_3D_2634.npy': 0,
#  'isaac_good_scaled_kpts_3D_1183.npy': 0,
#  'amruthok1_scaled_kpts_3D_4109.npy': 1,
#  'amruthok1_scaled_kpts_3D_2377.npy': 1,
#  'eddie_good1_scaled_kpts_3D_3132.npy': 0,
#  'eddie_good1_scaled_kpts_3D_2002.npy': 0,
#  'daniel_ok_scaled_kpts_3D_2784.npy': 1,
#  'michael_good_scaled_kpts_3D_1442.npy': 0,
#  'amruthok1_scaled_kpts_3D_4087.npy': 1,
#  'daniel_good_scaled_kpts_3D_874.npy': 0,
#  'isaac_ok_2_scaled_kpts_3D_1904.npy': 1,
#  'chris_buff_3d_1993_ok.npy': 1,
#  'michael_bad_scaled_kpts_3D_976.npy': 1,
#  'chris_bad1_scaled_kpts_3D_1927.npy': 1,
#  'isaac_good_scaled_kpts_3D_4089.npy': 0,
#  'connor_ok_scaled_kpts_3D_3167.npy': 1,
#  'amruthok2_scaled_kpts_3D_398.npy': 1,
#  'amruth_bad1_3D_1690.npy': 1,
#  'chris_buff_3d_6318_ok.npy': 1,
#  'connor_ok_scaled_kpts_3D_2284.npy': 1,
#  'chris_good0_scaled_kpts_3D_2353.npy': 0,
#  'chris_good0_scaled_kpts_3D_2486.npy': 0,
#  'chris_bad1_scaled_kpts_3D_2833.npy': 1,
#  'daniel_bad_scaled_kpts_3D_695.npy': 1,
#  'chris_bad0_scaled_kpts_3D_651.npy': 1,
#  'amruthbad2_scaled_kpts_3D_3930.npy': 1,
#  'eddie_good0_scaled_kpts_3D_3189.npy': 0,
#  'isaac_good_scaled_kpts_3D_3243.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_465.npy': 1,
#  'amruthgood1_scaled_kpts_3D_2569.npy': 0,
#  'amruthok2_scaled_kpts_3D_3534.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_4206.npy': 1,
#  'isaac_ok_scaled_kpts_3D_1866.npy': 1,
#  'eddie_good0_scaled_kpts_3D_2877.npy': 0,
#  'amruthgood1_scaled_kpts_3D_334.npy': 0,
#  'daniel_ok_scaled_kpts_3D_1631.npy': 1,
#  'isaac_good_scaled_kpts_3D_20.npy': 0,
#  'amruthgood1_scaled_kpts_3D_5.npy': 0,
#  'chris_ok_scaled_kpts_3D_3627.npy': 1,
#  'chris_ok_scaled_kpts_3D_1257.npy': 1,
#  'amruthbad2_scaled_kpts_3D_2931.npy': 1,
#  'amruth_bad1_3D_1709.npy': 1,
#  'isaac_good_scaled_kpts_3D_2151.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_1358.npy': 1,
#  'amruthbad2_scaled_kpts_3D_4158.npy': 1,
#  'chris_bad0_scaled_kpts_3D_2428.npy': 1,
#  'amruthgood1_scaled_kpts_3D_388.npy': 0,
#  'amruthok1_scaled_kpts_3D_3435.npy': 1,
#  'amruthok2_scaled_kpts_3D_3234.npy': 1,
#  'chris_ok_scaled_kpts_3D_3361.npy': 1,
#  'chris_ok_scaled_kpts_3D_2391.npy': 1,
#  'eddie_good1_scaled_kpts_3D_3520.npy': 0,
#  'eddie_ok_scaled_kpts_3D_3096.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_2085.npy': 1,
#  'michael_ok_scaled_kpts_3D_2088.npy': 1,
#  'eddie_ok_scaled_kpts_3D_4280.npy': 1,
#  'amruthbad2_scaled_kpts_3D_4244.npy': 1,
#  'chris_bad1_scaled_kpts_3D_333.npy': 1,
#  'connor_good_scaled_kpts_3D_1851.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_3506.npy': 1,
#  'daniel_ok_scaled_kpts_3D_2380.npy': 1,
#  'amruthgood1_scaled_kpts_3D_2272.npy': 0,
#  'michael_bad_scaled_kpts_3D_872.npy': 1,
#  'connor_bad_scaled_kpts_3D_496.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1442.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_768.npy': 1,
#  'chris_good0_scaled_kpts_3D_3517.npy': 0,
#  'daniel_ok_scaled_kpts_3D_2815.npy': 1,
#  'michael_ok_scaled_kpts_3D_1177.npy': 1,
#  'eddie_good1_scaled_kpts_3D_2374.npy': 0,
#  'daniel_bad_scaled_kpts_3D_1640.npy': 1,
#  'amruthbad2_scaled_kpts_3D_3148.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_4074.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_1711.npy': 0,
#  'isaac_ok_scaled_kpts_3D_3525.npy': 1,
#  'daniel_ok_scaled_kpts_3D_3065.npy': 1,
#  'eddie_good1_scaled_kpts_3D_3321.npy': 0,
#  'chris_buff_3d_255_ok.npy': 1,
#  'amruthok2_scaled_kpts_3D_3643.npy': 1,
#  'amruthok2_scaled_kpts_3D_3101.npy': 1,
#  'chris_buff_3d_7177_ok.npy': 1,
#  'isaac_good_scaled_kpts_3D_1018.npy': 0,
#  'amruthgood2_scaled_kpts_3D_2070.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_3800.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1308.npy': 0,
#  'chris_good1_scaled_kpts_3D_4377.npy': 0,
#  'amruthgood2_scaled_kpts_3D_2143.npy': 0,
#  'chris_bad0_scaled_kpts_3D_2663.npy': 1,
#  'connor_ok_scaled_kpts_3D_3354.npy': 1,
#  'isaac_bad_scaled_kpts_3D_3727.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_3209.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1443.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_749.npy': 0,
#  'connor_bad_scaled_kpts_3D_221.npy': 1,
#  'amruth_bad1_3D_1086.npy': 1,
#  'chris_good1_scaled_kpts_3D_1685.npy': 0,
#  'michael_good_scaled_kpts_3D_624.npy': 0,
#  'amruthgood2_scaled_kpts_3D_2685.npy': 0,
#  'chris_buff_3d_8614_ok.npy': 1,
#  'chris_bad1_scaled_kpts_3D_2138.npy': 1,
#  'chris_buff_3d_3671_ok.npy': 1,
#  'michael_bad_scaled_kpts_3D_2250.npy': 1,
#  'chris_ok_scaled_kpts_3D_3776.npy': 1,
#  'isaac_bad_scaled_kpts_3D_2139.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_3298.npy': 1,
#  'amruthgood2_scaled_kpts_3D_4102.npy': 0,
#  'connor_good_scaled_kpts_3D_2484.npy': 0,
#  'connor_good_scaled_kpts_3D_1310.npy': 0,
#  'amruthok1_scaled_kpts_3D_4093.npy': 1,
#  'connor_ok_scaled_kpts_3D_1317.npy': 1,
#  'chris_ok_scaled_kpts_3D_778.npy': 1,
#  'amruthbad2_scaled_kpts_3D_3688.npy': 1,
#  'connor_good_scaled_kpts_3D_1877.npy': 0,
#  'connor_ok_scaled_kpts_3D_515.npy': 1,
#  'michael_bad_scaled_kpts_3D_717.npy': 1,
#  'connor_good_scaled_kpts_3D_230.npy': 0,
#  'isaac_ok_2_scaled_kpts_3D_1240.npy': 1,
#  'chris_ok_scaled_kpts_3D_1902.npy': 1,
#  'amruthgood2_scaled_kpts_3D_2714.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_2522.npy': 0,
#  'daniel_bad_scaled_kpts_3D_2136.npy': 1,
#  'daniel_good_scaled_kpts_3D_1022.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_1236.npy': 1,
#  'amruthok1_scaled_kpts_3D_1632.npy': 1,
#  'michael_good_scaled_kpts_3D_97.npy': 0,
#  'michael_ok_scaled_kpts_3D_3122.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1156.npy': 1,
#  'amruthok2_scaled_kpts_3D_1513.npy': 1,
#  'connor_ok_scaled_kpts_3D_2913.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_4247.npy': 0,
#  'michael_ok_scaled_kpts_3D_692.npy': 1,
#  'eddie_good0_scaled_kpts_3D_2471.npy': 0,
#  'chris_good0_scaled_kpts_3D_881.npy': 0,
#  'chris_ok_scaled_kpts_3D_3210.npy': 1,
#  'michael_good_scaled_kpts_3D_2767.npy': 0,
#  'amruthbad2_scaled_kpts_3D_321.npy': 1,
#  'chris_bad0_scaled_kpts_3D_1961.npy': 1,
#  'isaac_bad_scaled_kpts_3D_3328.npy': 1,
#  'isaac_ok_scaled_kpts_3D_3815.npy': 1,
#  'daniel_good_scaled_kpts_3D_1136.npy': 0,
#  'isaac_good_scaled_kpts_3D_3188.npy': 0,
#  'eddie_good1_scaled_kpts_3D_3476.npy': 0,
#  'chris_buff_3d_8034_ok.npy': 1,
#  'daniel_ok_scaled_kpts_3D_1984.npy': 1,
#  'amruth_bad1_3D_4242.npy': 1,
#  'amruthgood1_scaled_kpts_3D_280.npy': 0,
#  'eddie_good1_scaled_kpts_3D_1052.npy': 0,
#  'connor_ok_scaled_kpts_3D_2139.npy': 1,
#  'isaac_good_scaled_kpts_3D_3631.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_3376.npy': 1,
#  'eddie_ok_scaled_kpts_3D_742.npy': 1,
#  'amruthgood2_scaled_kpts_3D_2859.npy': 0,
#  'amruth_bad1_3D_934.npy': 1,
#  'michael_good_scaled_kpts_3D_1500.npy': 0,
#  'chris_buff_3d_4232_ok.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_984.npy': 1,
#  'daniel_good_scaled_kpts_3D_490.npy': 0,
#  'amruthok2_scaled_kpts_3D_588.npy': 1,
#  'isaac_ok_scaled_kpts_3D_3072.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_3414.npy': 1,
#  'chris_buff_3d_4254_ok.npy': 1,
#  'amruthgood2_scaled_kpts_3D_3679.npy': 0,
#  'isaac_ok_2_scaled_kpts_3D_2595.npy': 1,
#  'connor_bad_scaled_kpts_3D_64.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_3937.npy': 1,
#  'chris_bad1_scaled_kpts_3D_2791.npy': 1,
#  'eddie_good0_scaled_kpts_3D_2755.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_2550.npy': 1,
#  'isaac_bad_scaled_kpts_3D_3860.npy': 1,
#  'isaac_bad_scaled_kpts_3D_731.npy': 1,
#  'daniel_bad_scaled_kpts_3D_1036.npy': 1,
#  'eddie_good0_scaled_kpts_3D_153.npy': 0,
#  'michael_bad_scaled_kpts_3D_3353.npy': 1,
#  'eddie_ok_scaled_kpts_3D_456.npy': 1,
#  'isaac_bad_scaled_kpts_3D_2081.npy': 1,
#  'chris_buff_3d_4734_ok.npy': 1,
#  'isaac_good_scaled_kpts_3D_794.npy': 0,
#  'chris_bad1_scaled_kpts_3D_543.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1078.npy': 1,
#  'amruthgood1_scaled_kpts_3D_2940.npy': 0,
#  'isaac_bad_scaled_kpts_3D_2569.npy': 1,
#  'amruthgood2_scaled_kpts_3D_2298.npy': 0,
#  'amruth_bad1_3D_1231.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_3710.npy': 0,
#  'chris_good0_scaled_kpts_3D_2045.npy': 0,
#  'chris_buff_3d_8166_ok.npy': 1,
#  'chris_buff_3d_549_ok.npy': 1,
#  'chris_good0_scaled_kpts_3D_3377.npy': 0,
#  'eddie_ok_scaled_kpts_3D_3688.npy': 1,
#  'chris_ok_scaled_kpts_3D_1334.npy': 1,
#  'daniel_bad_scaled_kpts_3D_159.npy': 1,
#  'amruthbad2_scaled_kpts_3D_832.npy': 1,
#  'amruthok1_scaled_kpts_3D_2362.npy': 1,
#  'daniel_bad_scaled_kpts_3D_1692.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1769.npy': 0,
#  'chris_good1_scaled_kpts_3D_2563.npy': 0,
#  'eddie_ok_scaled_kpts_3D_1775.npy': 1,
#  'amruth_bad1_3D_915.npy': 1,
#  'chris_good0_scaled_kpts_3D_4538.npy': 0,
#  'daniel_bad_scaled_kpts_3D_1041.npy': 1,
#  'chris_good1_scaled_kpts_3D_1387.npy': 0,
#  'amruthbad2_scaled_kpts_3D_3573.npy': 1,
#  'connor_bad_scaled_kpts_3D_1938.npy': 1,
#  'chris_bad0_scaled_kpts_3D_3629.npy': 1,
#  'amruthgood2_scaled_kpts_3D_3944.npy': 0,
#  'isaac_ok_scaled_kpts_3D_4579.npy': 1,
#  'chris_buff_3d_2465_ok.npy': 1,
#  'chris_buff_3d_7051_ok.npy': 1,
#  'amruthok2_scaled_kpts_3D_191.npy': 1,
#  'michael_bad_scaled_kpts_3D_3333.npy': 1,
#  'connor_good_scaled_kpts_3D_3300.npy': 0,
#  'eddie_ok_scaled_kpts_3D_4209.npy': 1,
#  'michael_bad_scaled_kpts_3D_447.npy': 1,
#  'chris_bad0_scaled_kpts_3D_4124.npy': 1,
#  'eddie_good1_scaled_kpts_3D_4174.npy': 0,
#  'isaac_ok_scaled_kpts_3D_2848.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_1266.npy': 1,
#  'chris_good0_scaled_kpts_3D_2813.npy': 0,
#  'michael_bad_scaled_kpts_3D_3068.npy': 1,
#  'amruthgood2_scaled_kpts_3D_1322.npy': 0,
#  'connor_bad_scaled_kpts_3D_1932.npy': 1,
#  'daniel_ok_scaled_kpts_3D_1117.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_3944.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_1640.npy': 0,
#  'amruthok2_scaled_kpts_3D_2081.npy': 1,
#  'eddie_ok_scaled_kpts_3D_3601.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_2671.npy': 1,
#  'amruthok1_scaled_kpts_3D_1017.npy': 1,
#  'eddie_ok_scaled_kpts_3D_3600.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_4123.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_2132.npy': 1,
#  'eddie_good0_scaled_kpts_3D_885.npy': 0,
#  'amruthgood2_scaled_kpts_3D_1635.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_273.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_3241.npy': 1,
#  'chris_good1_scaled_kpts_3D_2791.npy': 0,
#  'connor_bad_scaled_kpts_3D_2211.npy': 1,
#  'michael_good_scaled_kpts_3D_503.npy': 0,
#  'chris_buff_3d_10089_ok.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1746.npy': 1,
#  'eddie_good1_scaled_kpts_3D_866.npy': 0,
#  'eddie_good0_scaled_kpts_3D_2000.npy': 0,
#  'chris_good1_scaled_kpts_3D_2567.npy': 0,
#  'daniel_bad_scaled_kpts_3D_3548.npy': 1,
#  'chris_buff_3d_10437_ok.npy': 1,
#  'daniel_ok_scaled_kpts_3D_2132.npy': 1,
#  'connor_good_scaled_kpts_3D_2661.npy': 0,
#  'eddie_ok_scaled_kpts_3D_3311.npy': 1,
#  'chris_buff_3d_3552_ok.npy': 1,
#  'daniel_good_scaled_kpts_3D_3479.npy': 0,
#  'connor_ok_scaled_kpts_3D_552.npy': 1,
#  'michael_good_scaled_kpts_3D_3104.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_1766.npy': 1,
#  'eddie_good1_scaled_kpts_3D_4467.npy': 0,
#  'isaac_ok_scaled_kpts_3D_2281.npy': 1,
#  'chris_buff_3d_9705_ok.npy': 1,
#  'eddie_good0_scaled_kpts_3D_1258.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_3666.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_1803.npy': 1,
#  'amruthbad2_scaled_kpts_3D_2769.npy': 1,
#  'amruthbad2_scaled_kpts_3D_2659.npy': 1,
#  'chris_buff_3d_10312_ok.npy': 1,
#  'amruthok1_scaled_kpts_3D_3387.npy': 1,
#  'connor_ok_scaled_kpts_3D_1462.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_307.npy': 1,
#  'amruthgood2_scaled_kpts_3D_1198.npy': 0,
#  'chris_good0_scaled_kpts_3D_1860.npy': 0,
#  'michael_bad_scaled_kpts_3D_1246.npy': 1,
#  'chris_buff_3d_7480_ok.npy': 1,
#  'connor_ok_scaled_kpts_3D_189.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_2216.npy': 0,
#  'chris_bad1_scaled_kpts_3D_1919.npy': 1,
#  'amruthgood1_scaled_kpts_3D_4382.npy': 0,
#  'eddie_ok_scaled_kpts_3D_3309.npy': 1,
#  'daniel_good_scaled_kpts_3D_2343.npy': 0,
#  'connor_ok_scaled_kpts_3D_140.npy': 1,
#  'isaac_good_scaled_kpts_3D_1525.npy': 0,
#  'michael_ok_scaled_kpts_3D_3072.npy': 1,
#  'amruthok2_scaled_kpts_3D_749.npy': 1,
#  'chris_buff_3d_3565_ok.npy': 1,
#  'chris_bad0_scaled_kpts_3D_2681.npy': 1,
#  'amruthgood2_scaled_kpts_3D_293.npy': 0,
#  'amruthok1_scaled_kpts_3D_2975.npy': 1,
#  'eddie_ok_scaled_kpts_3D_480.npy': 1,
#  'amruthgood1_scaled_kpts_3D_560.npy': 0,
#  'isaac_good_scaled_kpts_3D_2518.npy': 0,
#  'amruthok2_scaled_kpts_3D_1332.npy': 1,
#  'eddie_ok_scaled_kpts_3D_391.npy': 1,
#  'amruthok2_scaled_kpts_3D_565.npy': 1,
#  'connor_ok_scaled_kpts_3D_86.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3321.npy': 0,
#  'amruthgood2_scaled_kpts_3D_359.npy': 0,
#  'chris_good0_scaled_kpts_3D_2387.npy': 0,
#  'connor_good_scaled_kpts_3D_365.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_114.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_967.npy': 1,
#  'chris_good0_scaled_kpts_3D_1034.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_4343.npy': 0,
#  'chris_buff_3d_2596_ok.npy': 1,
#  'amruthok2_scaled_kpts_3D_3422.npy': 1,
#  'chris_good0_scaled_kpts_3D_255.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_3816.npy': 1,
#  'eddie_good0_scaled_kpts_3D_1482.npy': 0,
#  'connor_ok_scaled_kpts_3D_2348.npy': 1,
#  'isaac_ok_scaled_kpts_3D_1605.npy': 1,
#  'amruthok1_scaled_kpts_3D_2897.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1430.npy': 1,
#  'chris_good1_scaled_kpts_3D_2660.npy': 0,
#  'michael_good_scaled_kpts_3D_294.npy': 0,
#  'eddie_good1_scaled_kpts_3D_3693.npy': 0,
#  'isaac_bad_scaled_kpts_3D_2994.npy': 1,
#  'daniel_good_scaled_kpts_3D_3046.npy': 0,
#  'connor_bad_scaled_kpts_3D_3352.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_3033.npy': 1,
#  'michael_good_scaled_kpts_3D_3101.npy': 0,
#  'michael_ok_scaled_kpts_3D_2679.npy': 1,
#  'eddie_good0_scaled_kpts_3D_1691.npy': 0,
#  'isaac_ok_scaled_kpts_3D_4449.npy': 1,
#  'isaac_ok_scaled_kpts_3D_1087.npy': 1,
#  'chris_bad1_scaled_kpts_3D_858.npy': 1,
#  'isaac_ok_scaled_kpts_3D_457.npy': 1,
#  'amruthbad2_scaled_kpts_3D_1638.npy': 1,
#  'chris_ok_scaled_kpts_3D_3512.npy': 1,
#  'eddie_good0_scaled_kpts_3D_1002.npy': 0,
#  'connor_good_scaled_kpts_3D_1166.npy': 0,
#  'amruthgood1_scaled_kpts_3D_2231.npy': 0,
#  'amruthgood1_scaled_kpts_3D_780.npy': 0,
#  'connor_bad_scaled_kpts_3D_1661.npy': 1,
#  'eddie_ok_scaled_kpts_3D_3157.npy': 1,
#  'eddie_good0_scaled_kpts_3D_3690.npy': 0,
#  'michael_good_scaled_kpts_3D_1040.npy': 0,
#  'chris_good1_scaled_kpts_3D_3842.npy': 0,
#  'isaac_good_scaled_kpts_3D_506.npy': 0,
#  'chris_buff_3d_7488_ok.npy': 1,
#  'daniel_bad_scaled_kpts_3D_3452.npy': 1,
#  'daniel_good_scaled_kpts_3D_3329.npy': 0,
#  'amruthok2_scaled_kpts_3D_3619.npy': 1,
#  'isaac_bad_scaled_kpts_3D_4031.npy': 1,
#  'daniel_bad_scaled_kpts_3D_2973.npy': 1,
#  'daniel_bad_scaled_kpts_3D_3110.npy': 1,
#  'amruthok1_scaled_kpts_3D_2849.npy': 1,
#  'connor_good_scaled_kpts_3D_2058.npy': 0,
#  'isaac_ok_2_scaled_kpts_3D_162.npy': 1,
#  'michael_ok_scaled_kpts_3D_1657.npy': 1,
#  'amruthok2_scaled_kpts_3D_2773.npy': 1,
#  'chris_bad1_scaled_kpts_3D_2558.npy': 1,
#  'isaac_good_scaled_kpts_3D_3297.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_164.npy': 0,
#  'chris_bad0_scaled_kpts_3D_1490.npy': 1,
#  'chris_buff_3d_1398_ok.npy': 1,
#  'michael_ok_scaled_kpts_3D_85.npy': 1,
#  'amruthok1_scaled_kpts_3D_3964.npy': 1,
#  'chris_ok_scaled_kpts_3D_2856.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1518.npy': 0,
#  'amruthbad2_scaled_kpts_3D_3331.npy': 1,
#  'amruthbad2_scaled_kpts_3D_4189.npy': 1,
#  'chris_buff_3d_4007_ok.npy': 1,
#  'connor_bad_scaled_kpts_3D_942.npy': 1,
#  'michael_good_scaled_kpts_3D_2741.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_1973.npy': 1,
#  'eddie_ok_scaled_kpts_3D_2015.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_535.npy': 0,
#  'eddie_good0_scaled_kpts_3D_3239.npy': 0,
#  'amruthok1_scaled_kpts_3D_518.npy': 1,
#  'daniel_bad_scaled_kpts_3D_2638.npy': 1,
#  'daniel_ok_scaled_kpts_3D_2723.npy': 1,
#  'michael_good_scaled_kpts_3D_2102.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_3786.npy': 0,
#  'chris_buff_3d_3907_ok.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_1404.npy': 1,
#  'chris_good0_scaled_kpts_3D_2518.npy': 0,
#  'connor_bad_scaled_kpts_3D_2408.npy': 1,
#  'amruthok1_scaled_kpts_3D_78.npy': 1,
#  'isaac_bad_scaled_kpts_3D_52.npy': 1,
#  'chris_bad1_scaled_kpts_3D_2087.npy': 1,
#  'michael_good_scaled_kpts_3D_3603.npy': 0,
#  'amruth_bad1_3D_3869.npy': 1,
#  'amruthok1_scaled_kpts_3D_2414.npy': 1,
#  'daniel_bad_scaled_kpts_3D_277.npy': 1,
#  'amruthok1_scaled_kpts_3D_146.npy': 1,
#  'eddie_good0_scaled_kpts_3D_2168.npy': 0,
#  'michael_bad_scaled_kpts_3D_2939.npy': 1,
#  'connor_good_scaled_kpts_3D_2695.npy': 0,
#  'chris_buff_3d_7028_ok.npy': 1,
#  'eddie_good0_scaled_kpts_3D_3651.npy': 0,
#  'connor_ok_scaled_kpts_3D_214.npy': 1,
#  'michael_ok_scaled_kpts_3D_2925.npy': 1,
#  'michael_good_scaled_kpts_3D_899.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_1558.npy': 1,
#  'chris_ok_scaled_kpts_3D_301.npy': 1,
#  'eddie_good0_scaled_kpts_3D_4229.npy': 0,
#  'michael_ok_scaled_kpts_3D_1880.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_3851.npy': 1,
#  'michael_good_scaled_kpts_3D_2104.npy': 0,
#  'michael_bad_scaled_kpts_3D_470.npy': 1,
#  'chris_good0_scaled_kpts_3D_6.npy': 0,
#  'amruthok1_scaled_kpts_3D_634.npy': 1,
#  'connor_ok_scaled_kpts_3D_312.npy': 1,
#  'michael_ok_scaled_kpts_3D_1892.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1083.npy': 0,
#  'amruthok2_scaled_kpts_3D_1434.npy': 1,
#  'eddie_ok_scaled_kpts_3D_2172.npy': 1,
#  'eddie_good0_scaled_kpts_3D_4393.npy': 0,
#  'chris_ok_scaled_kpts_3D_164.npy': 1,
#  'michael_bad_scaled_kpts_3D_2904.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_3254.npy': 0,
#  'eddie_good0_scaled_kpts_3D_4385.npy': 0,
#  'amruthbad2_scaled_kpts_3D_856.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1337.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_4407.npy': 1,
#  'amruthbad2_scaled_kpts_3D_593.npy': 1,
#  'isaac_bad_scaled_kpts_3D_4000.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_3444.npy': 1,
#  'isaac_bad_scaled_kpts_3D_4506.npy': 1,
#  'chris_good0_scaled_kpts_3D_4399.npy': 0,
#  'eddie_good1_scaled_kpts_3D_2216.npy': 0,
#  'eddie_good0_scaled_kpts_3D_1547.npy': 0,
#  'amruthgood1_scaled_kpts_3D_4244.npy': 0,
#  'michael_bad_scaled_kpts_3D_3788.npy': 1,
#  'amruthbad2_scaled_kpts_3D_2317.npy': 1,
#  'michael_bad_scaled_kpts_3D_3517.npy': 1,
#  'eddie_ok_scaled_kpts_3D_3631.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_2015.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1552.npy': 1,
#  'connor_bad_scaled_kpts_3D_292.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1420.npy': 1,
#  'eddie_ok_scaled_kpts_3D_4053.npy': 1,
#  'eddie_good0_scaled_kpts_3D_1958.npy': 0,
#  'chris_bad0_scaled_kpts_3D_2944.npy': 1,
#  'chris_buff_3d_8770_ok.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_4054.npy': 0,
#  'connor_bad_scaled_kpts_3D_911.npy': 1,
#  'eddie_good0_scaled_kpts_3D_3691.npy': 0,
#  'isaac_good_scaled_kpts_3D_4337.npy': 0,
#  'isaac_ok_scaled_kpts_3D_4303.npy': 1,
#  'connor_bad_scaled_kpts_3D_2686.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_2260.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_1371.npy': 1,
#  'michael_good_scaled_kpts_3D_451.npy': 0,
#  'isaac_good_scaled_kpts_3D_2884.npy': 0,
#  'chris_buff_3d_529_ok.npy': 1,
#  'isaac_ok_scaled_kpts_3D_3791.npy': 1,
#  'amruthok1_scaled_kpts_3D_4156.npy': 1,
#  'chris_buff_3d_8041_ok.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_1195.npy': 1,
#  'daniel_good_scaled_kpts_3D_91.npy': 0,
#  'amruthbad2_scaled_kpts_3D_2448.npy': 1,
#  'amruthgood2_scaled_kpts_3D_653.npy': 0,
#  'connor_bad_scaled_kpts_3D_1022.npy': 1,
#  'chris_buff_3d_985_ok.npy': 1,
#  'eddie_good0_scaled_kpts_3D_439.npy': 0,
#  'isaac_good_scaled_kpts_3D_1824.npy': 0,
#  'connor_bad_scaled_kpts_3D_3372.npy': 1,
#  'daniel_bad_scaled_kpts_3D_3008.npy': 1,
#  'amruthgood2_scaled_kpts_3D_3467.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_2800.npy': 1,
#  'chris_buff_3d_7291_ok.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_2902.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3056.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_4087.npy': 1,
#  'chris_bad0_scaled_kpts_3D_3446.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1956.npy': 0,
#  'chris_bad0_scaled_kpts_3D_698.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_617.npy': 1,
#  'daniel_bad_scaled_kpts_3D_2414.npy': 1,
#  'chris_good0_scaled_kpts_3D_1343.npy': 0,
#  'amruthgood2_scaled_kpts_3D_991.npy': 0,
#  'eddie_good1_scaled_kpts_3D_258.npy': 0,
#  'amruthok2_scaled_kpts_3D_1809.npy': 1,
#  'connor_ok_scaled_kpts_3D_1232.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_215.npy': 0,
#  'amruthok2_scaled_kpts_3D_3958.npy': 1,
#  'connor_ok_scaled_kpts_3D_1213.npy': 1,
#  'amruthbad2_scaled_kpts_3D_3873.npy': 1,
#  'isaac_good_scaled_kpts_3D_3986.npy': 0,
#  'chris_bad0_scaled_kpts_3D_1053.npy': 1,
#  'chris_buff_3d_9884_ok.npy': 1,
#  'chris_good1_scaled_kpts_3D_3223.npy': 0,
#  'connor_good_scaled_kpts_3D_176.npy': 0,
#  'chris_bad0_scaled_kpts_3D_3074.npy': 1,
#  'chris_ok_scaled_kpts_3D_4374.npy': 1,
#  'michael_ok_scaled_kpts_3D_1782.npy': 1,
#  'michael_bad_scaled_kpts_3D_3965.npy': 1,
#  'amruthgood2_scaled_kpts_3D_3656.npy': 0,
#  'amruthgood2_scaled_kpts_3D_3852.npy': 0,
#  'daniel_ok_scaled_kpts_3D_2322.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1361.npy': 0,
#  'amruthbad2_scaled_kpts_3D_2038.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_2153.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_3787.npy': 1,
#  'connor_good_scaled_kpts_3D_1977.npy': 0,
#  'daniel_ok_scaled_kpts_3D_409.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1766.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_345.npy': 1,
#  'isaac_good_scaled_kpts_3D_235.npy': 0,
#  'daniel_bad_scaled_kpts_3D_202.npy': 1,
#  'amruthgood2_scaled_kpts_3D_2326.npy': 0,
#  'isaac_ok_2_scaled_kpts_3D_3510.npy': 1,
#  'chris_good1_scaled_kpts_3D_3281.npy': 0,
#  'chris_bad0_scaled_kpts_3D_3623.npy': 1,
#  'michael_ok_scaled_kpts_3D_1505.npy': 1,
#  'eddie_good1_scaled_kpts_3D_2527.npy': 0,
#  'amruth_bad1_3D_1890.npy': 1,
#  'chris_ok_scaled_kpts_3D_3241.npy': 1,
#  'connor_bad_scaled_kpts_3D_2829.npy': 1,
#  'michael_bad_scaled_kpts_3D_3399.npy': 1,
#  'isaac_bad_scaled_kpts_3D_2857.npy': 1,
#  'amruthok1_scaled_kpts_3D_2257.npy': 1,
#  'amruthgood1_scaled_kpts_3D_2648.npy': 0,
#  'daniel_ok_scaled_kpts_3D_3480.npy': 1,
#  'amruthok1_scaled_kpts_3D_2704.npy': 1,
#  'amruthok1_scaled_kpts_3D_305.npy': 1,
#  'isaac_ok_scaled_kpts_3D_1126.npy': 1,
#  'amruthgood1_scaled_kpts_3D_1051.npy': 0,
#  'chris_buff_3d_6157_ok.npy': 1,
#  'chris_ok_scaled_kpts_3D_3694.npy': 1,
#  'eddie_good1_scaled_kpts_3D_2409.npy': 0,
#  'chris_buff_3d_7607_ok.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1936.npy': 1,
#  'amruthok2_scaled_kpts_3D_1738.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_3438.npy': 1,
#  'chris_bad0_scaled_kpts_3D_2452.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_659.npy': 0,
#  'chris_buff_3d_2908_ok.npy': 1,
#  'chris_buff_3d_8842_ok.npy': 1,
#  'chris_buff_3d_1581_ok.npy': 1,
#  'michael_ok_scaled_kpts_3D_1585.npy': 1,
#  'isaac_bad_scaled_kpts_3D_879.npy': 1,
#  'isaac_bad_scaled_kpts_3D_2610.npy': 1,
#  'michael_good_scaled_kpts_3D_919.npy': 0,
#  'daniel_ok_scaled_kpts_3D_2728.npy': 1,
#  'eddie_good1_scaled_kpts_3D_1613.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_4421.npy': 1,
#  'connor_ok_scaled_kpts_3D_2199.npy': 1,
#  'daniel_good_scaled_kpts_3D_3310.npy': 0,
#  'daniel_ok_scaled_kpts_3D_2592.npy': 1,
#  'isaac_ok_scaled_kpts_3D_3617.npy': 1,
#  'amruthok2_scaled_kpts_3D_355.npy': 1,
#  'chris_ok_scaled_kpts_3D_2603.npy': 1,
#  'chris_buff_3d_8686_ok.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_2366.npy': 0,
#  'amruth_bad1_3D_307.npy': 1,
#  'daniel_good_scaled_kpts_3D_1053.npy': 0,
#  'eddie_good1_scaled_kpts_3D_1405.npy': 0,
#  'eddie_good0_scaled_kpts_3D_2624.npy': 0,
#  'amruthok2_scaled_kpts_3D_3691.npy': 1,
#  'amruth_bad1_3D_2548.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_1770.npy': 1,
#  'chris_ok_scaled_kpts_3D_4445.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_779.npy': 1,
#  'connor_good_scaled_kpts_3D_49.npy': 0,
#  'chris_bad1_scaled_kpts_3D_580.npy': 1,
#  'daniel_bad_scaled_kpts_3D_860.npy': 1,
#  'daniel_good_scaled_kpts_3D_1632.npy': 0,
#  'chris_bad1_scaled_kpts_3D_29.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1323.npy': 1,
#  'amruthok2_scaled_kpts_3D_3612.npy': 1,
#  'eddie_ok_scaled_kpts_3D_3331.npy': 1,
#  'chris_buff_3d_6517_ok.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_2131.npy': 0,
#  'amruthgood1_scaled_kpts_3D_1698.npy': 0,
#  'amruth_bad1_3D_2300.npy': 1,
#  'chris_bad1_scaled_kpts_3D_2170.npy': 1,
#  'amruthok2_scaled_kpts_3D_1448.npy': 1,
#  'eddie_good1_scaled_kpts_3D_2486.npy': 0,
#  'michael_bad_scaled_kpts_3D_516.npy': 1,
#  'amruthok1_scaled_kpts_3D_878.npy': 1,
#  'amruthok2_scaled_kpts_3D_1318.npy': 1,
#  'amruthok1_scaled_kpts_3D_2422.npy': 1,
#  'chris_bad1_scaled_kpts_3D_2181.npy': 1,
#  'eddie_ok_scaled_kpts_3D_4190.npy': 1,
#  'eddie_good0_scaled_kpts_3D_1786.npy': 0,
#  'amruthgood2_scaled_kpts_3D_2475.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_1521.npy': 1,
#  'daniel_ok_scaled_kpts_3D_2968.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_747.npy': 0,
#  'amruthbad2_scaled_kpts_3D_2191.npy': 1,
#  'amruthbad2_scaled_kpts_3D_2807.npy': 1,
#  'daniel_good_scaled_kpts_3D_1414.npy': 0,
#  'chris_buff_3d_843_ok.npy': 1,
#  'isaac_ok_scaled_kpts_3D_2120.npy': 1,
#  'amruthok1_scaled_kpts_3D_3776.npy': 1,
#  'chris_buff_3d_6747_ok.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_2099.npy': 0,
#  'connor_good_scaled_kpts_3D_922.npy': 0,
#  'eddie_good1_scaled_kpts_3D_2256.npy': 0,
#  'chris_good1_scaled_kpts_3D_975.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_4164.npy': 1,
#  'daniel_bad_scaled_kpts_3D_939.npy': 1,
#  'michael_bad_scaled_kpts_3D_1335.npy': 1,
#  'connor_ok_scaled_kpts_3D_1548.npy': 1,
#  'amruthok2_scaled_kpts_3D_129.npy': 1,
#  'michael_ok_scaled_kpts_3D_1095.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3221.npy': 0,
#  'chris_ok_scaled_kpts_3D_4227.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_1687.npy': 0,
#  'daniel_bad_scaled_kpts_3D_2154.npy': 1,
#  'daniel_ok_scaled_kpts_3D_1230.npy': 1,
#  'daniel_ok_scaled_kpts_3D_1392.npy': 1,
#  'amruthok1_scaled_kpts_3D_3909.npy': 1,
#  'connor_ok_scaled_kpts_3D_2670.npy': 1,
#  'connor_ok_scaled_kpts_3D_2226.npy': 1,
#  'connor_ok_scaled_kpts_3D_2414.npy': 1,
#  'daniel_good_scaled_kpts_3D_2400.npy': 0,
#  'isaac_bad_scaled_kpts_3D_2542.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_2999.npy': 1,
#  'isaac_good_scaled_kpts_3D_2783.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_2836.npy': 1,
#  'connor_ok_scaled_kpts_3D_2202.npy': 1,
#  'amruthgood2_scaled_kpts_3D_406.npy': 0,
#  'eddie_ok_scaled_kpts_3D_1016.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1839.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_4382.npy': 1,
#  'amruthok2_scaled_kpts_3D_3260.npy': 1,
#  'amruth_bad1_3D_830.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_1034.npy': 1,
#  'michael_ok_scaled_kpts_3D_7.npy': 1,
#  'connor_ok_scaled_kpts_3D_1881.npy': 1,
#  'amruthok1_scaled_kpts_3D_1188.npy': 1,
#  'chris_buff_3d_5412_ok.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_3905.npy': 1,
#  'connor_good_scaled_kpts_3D_1680.npy': 0,
#  'isaac_ok_scaled_kpts_3D_939.npy': 1,
#  'michael_bad_scaled_kpts_3D_3162.npy': 1,
#  'amruthgood2_scaled_kpts_3D_4261.npy': 0,
#  'michael_ok_scaled_kpts_3D_3054.npy': 1,
#  'michael_ok_scaled_kpts_3D_2824.npy': 1,
#  'amruthok2_scaled_kpts_3D_1298.npy': 1,
#  'daniel_ok_scaled_kpts_3D_271.npy': 1,
#  'michael_bad_scaled_kpts_3D_2863.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3104.npy': 0,
#  'chris_buff_3d_5076_ok.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_3724.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1571.npy': 1,
#  'michael_bad_scaled_kpts_3D_967.npy': 1,
#  'amruth_bad1_3D_3103.npy': 1,
#  'eddie_good0_scaled_kpts_3D_297.npy': 0,
#  'daniel_good_scaled_kpts_3D_581.npy': 0,
#  'amruth_bad1_3D_3886.npy': 1,
#  'isaac_ok_scaled_kpts_3D_2763.npy': 1,
#  'amruthgood2_scaled_kpts_3D_857.npy': 0,
#  'isaac_good_scaled_kpts_3D_166.npy': 0,
#  'eddie_good1_scaled_kpts_3D_3205.npy': 0,
#  'isaac_bad_scaled_kpts_3D_652.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_1714.npy': 1,
#  'connor_bad_scaled_kpts_3D_2498.npy': 1,
#  'daniel_good_scaled_kpts_3D_2272.npy': 0,
#  'eddie_good0_scaled_kpts_3D_2047.npy': 0,
#  'amruthgood1_scaled_kpts_3D_1345.npy': 0,
#  'michael_bad_scaled_kpts_3D_3962.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_1262.npy': 0,
#  'amruthgood1_scaled_kpts_3D_3267.npy': 0,
#  'eddie_good0_scaled_kpts_3D_2177.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_0.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_4199.npy': 1,
#  'michael_ok_scaled_kpts_3D_874.npy': 1,
#  'chris_bad1_scaled_kpts_3D_1048.npy': 1,
#  'amruthbad2_scaled_kpts_3D_4308.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_4057.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_4357.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_1299.npy': 1,
#  'michael_ok_scaled_kpts_3D_890.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_2735.npy': 1,
#  'chris_good0_scaled_kpts_3D_2203.npy': 0,
#  'eddie_good0_scaled_kpts_3D_4070.npy': 0,
#  'connor_good_scaled_kpts_3D_884.npy': 0,
#  'daniel_good_scaled_kpts_3D_530.npy': 0,
#  'michael_bad_scaled_kpts_3D_2315.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_4433.npy': 1,
#  'chris_bad0_scaled_kpts_3D_3449.npy': 1,
#  'connor_good_scaled_kpts_3D_3176.npy': 0,
#  'amruthok2_scaled_kpts_3D_3061.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_1089.npy': 0,
#  'amruthok2_scaled_kpts_3D_886.npy': 1,
#  'amruthgood1_scaled_kpts_3D_3414.npy': 0,
#  'chris_bad0_scaled_kpts_3D_2390.npy': 1,
#  'chris_bad0_scaled_kpts_3D_1421.npy': 1,
#  'amruthok1_scaled_kpts_3D_3834.npy': 1,
#  'amruthgood1_scaled_kpts_3D_37.npy': 0,
#  'chris_ok_scaled_kpts_3D_1561.npy': 1,
#  'connor_good_scaled_kpts_3D_3140.npy': 0,
#  'amruthgood2_scaled_kpts_3D_44.npy': 0,
#  'isaac_good_scaled_kpts_3D_3788.npy': 0,
#  'isaac_good_2_scaled_kpts_3D_539.npy': 0,
#  'connor_bad_scaled_kpts_3D_869.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_534.npy': 1,
#  'amruthok2_scaled_kpts_3D_3963.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_2071.npy': 1,
#  'chris_buff_3d_4119_ok.npy': 1,
#  'connor_ok_scaled_kpts_3D_425.npy': 1,
#  'isaac_bad_scaled_kpts_3D_3928.npy': 1,
#  'eddie_good0_scaled_kpts_3D_680.npy': 0,
#  'eddie_ok_scaled_kpts_3D_1257.npy': 1,
#  'chris_bad0_scaled_kpts_3D_2862.npy': 1,
#  'amruthok2_scaled_kpts_3D_559.npy': 1,
#  'daniel_ok_scaled_kpts_3D_3178.npy': 1,
#  'chris_good0_scaled_kpts_3D_2005.npy': 0,
#  'chris_bad0_scaled_kpts_3D_4272.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_779.npy': 0,
#  'connor_good_scaled_kpts_3D_3229.npy': 0,
#  'chris_buff_3d_1437_ok.npy': 1,
#  'eddie_bad0_scaled_kpts_3D_115.npy': 1,
#  'michael_ok_scaled_kpts_3D_2082.npy': 1,
#  'amruthbad2_scaled_kpts_3D_1514.npy': 1,
#  'isaac_bad_scaled_kpts_3D_4434.npy': 1,
#  'isaac_bad_2_scaled_kpts_3D_2215.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_3708.npy': 0,
#  'connor_good_scaled_kpts_3D_1452.npy': 0,
#  'chris_bad1_scaled_kpts_3D_636.npy': 1,
#  'michael_good_scaled_kpts_3D_2290.npy': 0,
#  'chris_good1_scaled_kpts_3D_807.npy': 0,
#  'amruthgood1_scaled_kpts_3D_4270.npy': 0,
#  'amruthgood2_scaled_kpts_3D_2295.npy': 0,
#  'chris_bad0_scaled_kpts_3D_2260.npy': 1,
#  'daniel_ok_scaled_kpts_3D_476.npy': 1,
#  'chris_buff_3d_9824_ok.npy': 1,
#  'amruthbad2_scaled_kpts_3D_959.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_2168.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_533.npy': 1,
#  'chris_buff_3d_8502_ok.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_3196.npy': 0,
#  'isaac_bad_scaled_kpts_3D_124.npy': 1,
#  'isaac_ok_scaled_kpts_3D_2339.npy': 1,
#  'chris_buff_3d_3676_ok.npy': 1,
#  'chris_buff_3d_5972_ok.npy': 1,
#  'connor_good_scaled_kpts_3D_2461.npy': 0,
#  'chris_ok_scaled_kpts_3D_4065.npy': 1,
#  'eddie_good0_scaled_kpts_3D_2889.npy': 0,
#  'isaac_bad_scaled_kpts_3D_70.npy': 1,
#  'chris_good1_scaled_kpts_3D_1468.npy': 0,
#  'amruthok1_scaled_kpts_3D_3025.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_4214.npy': 0,
#  'eddie_ok_scaled_kpts_3D_1315.npy': 1,
#  'chris_bad1_scaled_kpts_3D_2078.npy': 1,
#  'michael_bad_scaled_kpts_3D_1857.npy': 1,
#  'chris_buff_3d_5507_ok.npy': 1,
#  'amruthgood2_scaled_kpts_3D_1929.npy': 0,
#  'eddie_good1_scaled_kpts_3D_1806.npy': 0,
#  'amruthok2_scaled_kpts_3D_4133.npy': 1,
#  'eddie_good1_scaled_kpts_3D_3771.npy': 0,
#  'isaac_bad_2_scaled_kpts_3D_2093.npy': 1,
#  'daniel_good_scaled_kpts_3D_1812.npy': 0,
#  'chris_bad0_scaled_kpts_3D_3210.npy': 1,
#  'amruthgood1_scaled_kpts_3D_933.npy': 0,
#  'chris_buff_3d_1571_ok.npy': 1,
#  'amruthok2_scaled_kpts_3D_254.npy': 1,
#  'michael_ok_scaled_kpts_3D_3011.npy': 1,
#  'isaac_ok_scaled_kpts_3D_3838.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1402.npy': 1,
#  'connor_good_scaled_kpts_3D_2492.npy': 0,
#  'eddie_ok_scaled_kpts_3D_1023.npy': 1,
#  'chris_buff_3d_2632_ok.npy': 1,
#  'daniel_ok_scaled_kpts_3D_2570.npy': 1,
#  'amruth_bad1_3D_2896.npy': 1,
#  'daniel_bad_scaled_kpts_3D_2282.npy': 1,
#  'eddie_ok_scaled_kpts_3D_1590.npy': 1,
#  'chris_bad1_scaled_kpts_3D_3167.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_1892.npy': 1,
#  'amruthok1_scaled_kpts_3D_2869.npy': 1,
#  'isaac_bad_scaled_kpts_3D_2245.npy': 1,
#  'amruth_bad1_3D_884.npy': 1,
#  'isaac_ok_scaled_kpts_3D_4639.npy': 1,
#  'chris_buff_3d_2165_ok.npy': 1,
#  'amruthgood1_scaled_kpts_3D_4429.npy': 0,
#  'chris_ok_scaled_kpts_3D_247.npy': 1,
#  'amruthbad2_scaled_kpts_3D_1548.npy': 1,
#  'chris_good1_scaled_kpts_3D_2022.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_728.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_4132.npy': 1,
#  'chris_buff_3d_7152_ok.npy': 1,
#  'daniel_good_scaled_kpts_3D_1230.npy': 0,
#  'chris_bad1_scaled_kpts_3D_2921.npy': 1,
#  'amruthok2_scaled_kpts_3D_181.npy': 1,
#  'chris_good0_scaled_kpts_3D_1737.npy': 0,
#  'chris_ok_scaled_kpts_3D_2994.npy': 1,
#  'eddie_good0_scaled_kpts_3D_2140.npy': 0,
#  'chris_buff_3d_3529_ok.npy': 1,
#  'eddie_good0_scaled_kpts_3D_3237.npy': 0,
#  'eddie_good0_scaled_kpts_3D_3292.npy': 0,
#  'eddie_bad1_scaled_kpts_3D_4239.npy': 1,
#  'eddie_good0_scaled_kpts_3D_747.npy': 0,
#  'chris_good1_scaled_kpts_3D_2527.npy': 0,
#  'daniel_ok_scaled_kpts_3D_416.npy': 1,
#  'connor_good_scaled_kpts_3D_1165.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_1757.npy': 1,
#  'chris_bad1_scaled_kpts_3D_1598.npy': 1,
#  'chris_good0_scaled_kpts_3D_925.npy': 0,
#  'amruthbad2_scaled_kpts_3D_2928.npy': 1,
#  'chris_good0_scaled_kpts_3D_1486.npy': 0,
#  'michael_ok_scaled_kpts_3D_300.npy': 1,
#  'chris_buff_3d_520_ok.npy': 1,
#  'daniel_bad_scaled_kpts_3D_972.npy': 1,
#  'isaac_bad_scaled_kpts_3D_1523.npy': 1,
#  'amruth_bad1_3D_1707.npy': 1,
#  'isaac_ok_2_scaled_kpts_3D_4259.npy': 1,
#  'amruthbad2_scaled_kpts_3D_790.npy': 1,
#  'daniel_good_scaled_kpts_3D_2290.npy': 0,
#  'chris_good0_scaled_kpts_3D_1239.npy': 0,
#  'eddie_good1_scaled_kpts_3D_1656.npy': 0,
#  'michael_bad_scaled_kpts_3D_1286.npy': 1,
#  'connor_bad_scaled_kpts_3D_2641.npy': 1,
#  'chris_bad1_scaled_kpts_3D_3053.npy': 1,
#  'isaac_good_2_scaled_kpts_3D_2004.npy': 0,
#  'chris_bad0_scaled_kpts_3D_607.npy': 1,
#  'amruth_bad1_3D_3980.npy': 1,
#  'eddie_bad1_scaled_kpts_3D_13.npy': 1,
#  'michael_bad_scaled_kpts_3D_810.npy': 1,
#  'amruthok1_scaled_kpts_3D_184.npy': 1,
#  'amruthbad2_scaled_kpts_3D_503.npy': 1,
#  'michael_ok_scaled_kpts_3D_3440.npy': 1,
#  'connor_good_scaled_kpts_3D_3282.npy': 0,
#  'eddie_bad0_scaled_kpts_3D_9.npy': 1,
#  'amruthok2_scaled_kpts_3D_2801.npy': 1,
#  'chris_good0_scaled_kpts_3D_3057.npy': 0,
#  'connor_good_scaled_kpts_3D_479.npy': 0,
#  'amruthok2_scaled_kpts_3D_2002.npy': 1,
#  'amruth_bad1_3D_2314.npy': 1,
#  'daniel_ok_scaled_kpts_3D_962.npy': 1,
#  'chris_good1_scaled_kpts_3D_3078.npy': 0,
#  'chris_bad0_scaled_kpts_3D_1086.npy': 1,
#  ...}

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels, dataset_dir, batch_size=64, dim=(17,3), n_classes=3, shuffle=True,):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.dataset_dir = dataset_dir
        self.list_IDs = list_IDs
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))
        # return len(self.list_IDs)

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim))
        y = np.empty((self.batch_size), dtype=int)

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            f = np.load(self.dataset_dir + ID)
            # reshaped = f.reshape(-1,3,1)
            # X[i,] = reshaped
            X[i] = f

            # Store class
            y[i] = self.labels[ID]

        return X, keras.utils.to_categorical(y, num_classes=self.n_classes)

# %%
params = {
    'dim': (10,3),
    'n_classes': 2,
}

train_datagen = DataGenerator(
    partition["train"], 
    labels, 
    dataset_dir=dataset_path,
    batch_size=BATCH_SIZE,
    shuffle=True,
    **params
)
val_datagen = DataGenerator(
    partition["val"],
    labels,
    dataset_dir=val_datapath,
    batch_size=BATCH_SIZE,
    # batch_size=1,
    shuffle=True,
    **params
)
test_datagen = DataGenerator(
    partition["test"],
    labels,
    dataset_dir=test_datapath,
    # dataset_dir=jeff_val,
    shuffle=False,
    batch_size=1,
    **params
)
print(len(train_datagen))
print(len(val_datagen))
print(len(test_datagen))
# Out:
# 560
# 2
# 697

# %%
kernel_rate =   regularizers.L1(0.0000531)
bias_rate =     regularizers.L1(0.1)
activity_rate = regularizers.L1(0.001)
dropout_rate = 0.050
model = models.Sequential()

model.add(layers.InputLayer(input_shape=(10,3)))
model.add(
    layers.Dense(
        units=150, activation='relu',
        kernel_regularizer=kernel_rate,
        bias_regularizer=bias_rate,
        activity_regularizer=activity_rate
    )
)
model.add(layers.Dropout(dropout_rate))
model.add(
    layers.Dense(
        units=150, activation='relu',
        kernel_regularizer=kernel_rate,
        bias_regularizer=bias_rate,
        activity_regularizer=activity_rate
    )
)
model.add(layers.Dropout(dropout_rate))
model.add(
    layers.Dense(
        units=150, activation='relu',
        kernel_regularizer=kernel_rate,
        bias_regularizer=bias_rate,
        activity_regularizer=activity_rate
    )
)
model.add(layers.Dropout(dropout_rate))
model.add(
    layers.Dense(
        units=150, activation='relu',
        kernel_regularizer=kernel_rate,
        bias_regularizer=bias_rate,
        activity_regularizer=activity_rate
    )
)
model.add(layers.Dropout(dropout_rate))
model.add(
    layers.Dense(
        units=150, activation='relu',
        kernel_regularizer=kernel_rate,
        bias_regularizer=bias_rate,
        activity_regularizer=activity_rate
    )
)
model.add(layers.Dropout(dropout_rate))
model.add(
    layers.Dense(
        units=150, activation='relu',
        kernel_regularizer=kernel_rate,
        bias_regularizer=bias_rate,
        activity_regularizer=activity_rate
    )
)
model.add(layers.Dropout(dropout_rate))
model.add(layers.Flatten())
model.add(layers.Dense(2, activation = 'softmax'))
model.summary()

# best performance: 3x12, 0.005 bias kernel 0.01 dropout 0.0008 lr
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10, 150)           600
#
#  dropout (Dropout)           (None, 10, 150)           0
#
#  dense_1 (Dense)             (None, 10, 150)           22650
#
#  dropout_1 (Dropout)         (None, 10, 150)           0
#
#  dense_2 (Dense)             (None, 10, 150)           22650
#
#  dropout_2 (Dropout)         (None, 10, 150)           0
#
#  dense_3 (Dense)             (None, 10, 150)           22650
#
#  dropout_3 (Dropout)         (None, 10, 150)           0
#
#  dense_4 (Dense)             (None, 10, 150)           22650
#
#  dropout_4 (Dropout)         (None, 10, 150)           0
#
#  dense_5 (Dense)             (None, 10, 150)           22650
#
#  dropout_5 (Dropout)         (None, 10, 150)           0
#
#  flatten (Flatten)           (None, 1500)              0
#
#  dense_6 (Dense)             (None, 2)                 3002
#
# =================================================================
# Total params: 116,852
# Trainable params: 116,852
# Non-trainable params: 0
# _________________________________________________________________
# 2022-05-25 22:34:48.661363: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:48.666114: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:48.666312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:48.666972: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-25 22:34:48.667607: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:48.667777: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:48.667946: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:49.022558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:49.022712: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:49.022827: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-25 22:34:49.022931: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4136 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
class PlotLearning(keras.callbacks.Callback):
    """
    Callback to plot the learning curves of the model during training.
    """
    def on_train_begin(self, logs={}):
        self.metrics = {}
        for metric in logs:
            self.metrics[metric] = []
            

    def on_epoch_end(self, epoch, logs={}):
        # Storing metrics
        for metric in logs:
            if metric in self.metrics:
                self.metrics[metric].append(logs.get(metric))
            else:
                self.metrics[metric] = [logs.get(metric)]
        
        # Plotting
        metrics = [x for x in logs if 'val' not in x]
        
        f, axs = plt.subplots(1, len(metrics), figsize=(15,5))
        clear_output(wait=True)

        for i, metric in enumerate(metrics):
            axs[i].plot(range(1, epoch + 2), 
                        self.metrics[metric], 
                        label=metric)
            if logs['val_' + metric]:
                axs[i].plot(range(1, epoch + 2), 
                            self.metrics['val_' + metric], 
                            label='val_' + metric)
                
            axs[i].legend()
            axs[i].grid()

        plt.tight_layout()
        plt.show()

# %%
# from tensorflow.keras.callbacks import Callback
# import tensorflow.keras.backend as K
class SGDRScheduler(tf.keras.callbacks.Callback):
    '''Cosine annealing learning rate scheduler with periodic restarts.
    # Usage
        ```python
            schedule = SGDRScheduler(min_lr=1e-5,
                                     max_lr=1e-2,
                                     steps_per_epoch=np.ceil(epoch_size/batch_size),
                                     lr_decay=0.9,
                                     cycle_length=5,
                                     mult_factor=1.5)
            model.fit(X_train, Y_train, epochs=100, callbacks=[schedule])
        ```
    # Arguments
        min_lr: The lower bound of the learning rate range for the experiment.
        max_lr: The upper bound of the learning rate range for the experiment.
        steps_per_epoch: Number of mini-batches in the dataset. Calculated as `np.ceil(epoch_size/batch_size)`. 
        lr_decay: Reduce the max_lr after the completion of each cycle.
                  Ex. To reduce the max_lr by 20% after each cycle, set this value to 0.8.
        cycle_length: Initial number of epochs in a cycle.
        mult_factor: Scale epochs_to_restart after each full cycle completion.
    # References
        Blog post: jeremyjordan.me/nn-learning-rate
        Original paper: http://arxiv.org/abs/1608.03983
    '''
    def __init__(self,
                 min_lr,
                 max_lr,
                 steps_per_epoch,
                 lr_decay=1,
                 cycle_length=10,
                 mult_factor=2):

        self.min_lr = min_lr
        self.max_lr = max_lr
        self.lr_decay = lr_decay

        self.batch_since_restart = 0
        self.next_restart = cycle_length

        self.steps_per_epoch = steps_per_epoch

        self.cycle_length = cycle_length
        self.mult_factor = mult_factor

        self.history = {}

    def clr(self):
        '''Calculate the learning rate.'''
        fraction_to_restart = self.batch_since_restart / (self.steps_per_epoch * self.cycle_length)
        lr = self.min_lr + 0.5 * (self.max_lr - self.min_lr) * (1 + np.cos(fraction_to_restart * np.pi))
        return lr

    def on_train_begin(self, logs={}):
        '''Initialize the learning rate to the minimum value at the start of training.'''
        logs = logs or {}
        tf.keras.backend.set_value(self.model.optimizer.lr, self.max_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(tf.keras.backend.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

        self.batch_since_restart += 1
        tf.keras.backend.set_value(self.model.optimizer.lr, self.clr())

    def on_epoch_end(self, epoch, logs={}):
        '''Check for end of current cycle, apply restarts when necessary.'''
        if epoch + 1 == self.next_restart:
            self.batch_since_restart = 0
            self.cycle_length = np.ceil(self.cycle_length * self.mult_factor)
            self.next_restart += self.cycle_length
            self.max_lr *= self.lr_decay
            self.best_weights = self.model.get_weights()

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

# lr_schedule = SGDRScheduler(min_lr=0.0008, max_lr=0.0063, steps_per_epoch=140, lr_decay=0.95, cycle_length=100)

# %%
# from tensorflow.keras.callbacks import Callback
# import tensorflow.keras.backend as K
class PlateauDestroyer(tf.keras.callbacks.Callback):
    def __init__(self,
                 og_lr,
                 steps_per_epoch,
                 epoch_to_jump_at,
                 number_of_high_epochs,
                 lr_new, lr_post):

        self.og_lr = og_lr
        self.steps_per_epoch = steps_per_epoch
        self.epoch_to_jump_at = epoch_to_jump_at
        self.number_of_high_epochs = number_of_high_epochs
        self.lr_new = lr_new
        self.lr_post = lr_post
        self.history = {}

    def on_train_begin(self, logs={}):
        logs = logs or {}
        tf.keras.backend.set_value(self.model.optimizer.lr, self.og_lr)

    def on_batch_end(self, batch, logs={}):
        '''Record previous batch statistics and update the learning rate.'''
        logs = logs or {}
        self.history.setdefault('lr', []).append(tf.keras.backend.get_value(self.model.optimizer.lr))
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

    def on_epoch_end(self, epoch, logs={}):
        if (epoch+1 >= self.epoch_to_jump_at and epoch+1 <= self.epoch_to_jump_at + self.number_of_high_epochs):
            lr = self.lr_new
            # print(epoch+1, lr)
        elif (epoch+1 > self.epoch_to_jump_at + self.number_of_high_epochs):
            lr = self.lr_post
        else: 
            lr = self.og_lr
            # print(epoch+1, lr)
        tf.keras.backend.set_value(self.model.optimizer.lr, lr)
        print(tf.keras.backend.get_value(self.model.optimizer.lr))

    def on_train_end(self, logs={}):
        '''Set weights to the values from the end of the most recent cycle for best performance.'''
        self.model.set_weights(self.best_weights)

plat_schedule = PlateauDestroyer(
    og_lr=0.0063, 
    steps_per_epoch=140, 
    epoch_to_jump_at=10, 
    number_of_high_epochs=10, 
    lr_new=10, 
    lr_post=0.0063
)

# %%
model_filepath = 'best_model.h5'
checkpoint = keras.callbacks.ModelCheckpoint('model_saves/model{epoch:05d}.h5', period=10) 
model_save = tf.keras.callbacks.ModelCheckpoint(
    model_filepath,
    monitor = "accuracy",
    verbose = 0,
    save_best_only = True,
    save_weights_only = False,
    mode = "max",
    save_freq = "epoch"
)
val_save = tf.keras.callbacks.ModelCheckpoint(
    "best_val.h5",
    monitor = "val_accuracy",
    verbose = 0,
    save_best_only = True,
    save_weights_only = False,
    mode = "max",
    save_freq = "epoch"
)
callback = [model_save, checkpoint, val_save, PlotLearning()]
# exp_sch = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.006,
#     decay_steps=50*140,
#     decay_rate=0.9,
#     staircase=True
# )
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0063),
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(
    train_datagen,
    epochs=50,
    steps_per_epoch=len(train_datagen) // 4,
    validation_data=val_datagen,
    validation_steps=len(val_datagen),
    shuffle=False,
    callbacks = callback,
    use_multiprocessing=True,
    workers=4
) 
# save history to disk
with open('history.pkl', 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# 140/140 [==============================] - 2s 13ms/step - loss: 0.7097 - accuracy: 0.6695 - val_loss: 0.7607 - val_accuracy: 0.5977
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=0'>1</a> history = model.fit(
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=1'>2</a>     train_datagen,
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=2'>3</a>     epochs=50,
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=3'>4</a>     steps_per_epoch=len(train_datagen) // 4,
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=4'>5</a>     validation_data=val_datagen,
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=5'>6</a>     validation_steps=len(val_datagen),
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=6'>7</a>     shuffle=False,
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=7'>8</a>     callbacks = callback,
#       <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=8'>9</a>     use_multiprocessing=True,
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=9'>10</a>     workers=4
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=10'>11</a> )
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=11'>12</a> # save history to disk
#      <a href='vscode-notebook-cell:/home/jeff/Documents/Code/StridedTransformer-Pose3D/datatrainer_finalattempt.ipynb#ch0000012?line=12'>13</a> with open('history.pkl', 'wb') as f:
#
# File ~/opencv-course/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/opencv-course/lib/python3.9/site-packages/keras/engine/training.py:1372, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/training.py?line=1368'>1369</a> data_handler._initial_epoch = (  # pylint: disable=protected-access
#    <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/training.py?line=1369'>1370</a>     self._maybe_load_initial_epoch_from_ckpt(initial_epoch))
#    <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/training.py?line=1370'>1371</a> logs = None
# -> <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/training.py?line=1371'>1372</a> for epoch, iterator in data_handler.enumerate_epochs():
#    <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/training.py?line=1372'>1373</a>   self.reset_metrics()
#    <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/training.py?line=1373'>1374</a>   callbacks.on_epoch_begin(epoch)
#
# File ~/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py:1198, in DataHandler.enumerate_epochs(self)
#    <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py?line=1195'>1196</a>   data_iterator = iter(self._dataset)
#    <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py?line=1196'>1197</a> yield epoch, data_iterator
# -> <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py?line=1197'>1198</a> self._adapter.on_epoch_end()
#
# File ~/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py:968, in KerasSequenceAdapter.on_epoch_end(self)
#     <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py?line=965'>966</a> def on_epoch_end(self):
#     <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py?line=966'>967</a>   if self._enqueuer:
# --> <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py?line=967'>968</a>     self._enqueuer.stop()
#     <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/engine/data_adapter.py?line=968'>969</a>   self._keras_sequence.on_epoch_end()
#
# File ~/opencv-course/lib/python3.9/site-packages/keras/utils/data_utils.py:662, in SequenceEnqueuer.stop(self, timeout)
#     <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/data_utils.py?line=659'>660</a>   self.queue.unfinished_tasks = 0
#     <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/data_utils.py?line=660'>661</a>   self.queue.not_full.notify()
# --> <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/data_utils.py?line=661'>662</a> self.run_thread.join(timeout)
#     <a href='file:///home/jeff/opencv-course/lib/python3.9/site-packages/keras/utils/data_utils.py?line=662'>663</a> _SHARED_SEQUENCES[self.uid] = None
#
# File /usr/lib/python3.9/threading.py:1053, in Thread.join(self, timeout)
#    <a href='file:///usr/lib/python3.9/threading.py?line=1049'>1050</a>     raise RuntimeError("cannot join current thread")
#    <a href='file:///usr/lib/python3.9/threading.py?line=1051'>1052</a> if timeout is None:
# -> <a href='file:///usr/lib/python3.9/threading.py?line=1052'>1053</a>     self._wait_for_tstate_lock()
#    <a href='file:///usr/lib/python3.9/threading.py?line=1053'>1054</a> else:
#    <a href='file:///usr/lib/python3.9/threading.py?line=1054'>1055</a>     # the behavior of a negative timeout isn't documented, but
#    <a href='file:///usr/lib/python3.9/threading.py?line=1055'>1056</a>     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    <a href='file:///usr/lib/python3.9/threading.py?line=1056'>1057</a>     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.9/threading.py:1069, in Thread._wait_for_tstate_lock(self, block, timeout)
#    <a href='file:///usr/lib/python3.9/threading.py?line=1066'>1067</a> if lock is None:  # already determined that the C code is done
#    <a href='file:///usr/lib/python3.9/threading.py?line=1067'>1068</a>     assert self._is_stopped
# -> <a href='file:///usr/lib/python3.9/threading.py?line=1068'>1069</a> elif lock.acquire(block, timeout):
#    <a href='file:///usr/lib/python3.9/threading.py?line=1069'>1070</a>     lock.release()
#    <a href='file:///usr/lib/python3.9/threading.py?line=1070'>1071</a>     self._stop()
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (15,7))

tr_losses = history.history['loss']
val_losses = history.history['val_loss']

tr_accs = history.history['accuracy']
val_accs = history.history['val_accuracy']

plt.plot(tr_losses, label = "train_loss")
plt.plot(val_losses, label = "val_loss")
plt.ylim(0.52, 0.56)
plt.xlabel("Number of epochs")
plt.ylabel("Cost (J)")
plt.grid()
plt.legend()
plt.show()

plt.figure(figsize = (15,7))

plt.plot(tr_accs, label = "acc_train")
plt.plot(val_accs, label = "acc_val")
plt.xlabel("Number of epochs")
# plt.xlim(0, 1000)
plt.ylabel("Accuracy")
plt.grid()
plt.legend()
plt.show()

# %%
test_model = tf.keras.models.load_model('best_model.h5')
val_model = tf.keras.models.load_model('best_val.h5')
epoch_model = tf.keras.models.load_model('model_saves/model00100.h5')

import matplotlib.patheffects as PathEffects
import itertools
def plot_confusion_matrix(cm, classes, normalise = False, title = 'Confusion matrix', cmap = plt.cm.RdYlGn):
    
    plt.imshow(cm, interpolation = 'nearest', cmap = cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation = 45)
    plt.yticks(tick_marks, classes)

    if normalise:
        cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]
        cm = cm.round(2)

    thresh = cm.max() / 1.1
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        txt =  plt.text(
            j, i, cm[i, j],
            horizontalalignment = "center",
            color = "white",
            size = 16
        )
        txt.set_path_effects([PathEffects.withStroke(linewidth=3, foreground='black')])
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

val_datagen = DataGenerator(
    partition["val"],
    labels,
    dataset_dir=val_datapath,
    # batch_size=BATCH_SIZE,
    batch_size=1,
    shuffle=False,
    **params
)

def graph_predictions(model, datagen, classes, title): 
    predictions = model.predict(
        datagen,
        verbose = 1,
    )
    predictions.squeeze().argmax(axis = -1)
    classification__report = classification_report(
        classes, 
        predictions.squeeze().argmax(axis = 1)
    )
    confusion__matrix = confusion_matrix(
        classes,
        predictions.squeeze().argmax(axis = 1)
    )
    np.set_printoptions(precision = 2)
    fig2 = plt.figure(figsize = (7,6))
    plot_confusion_matrix(
        confusion__matrix,
        classes = np.unique(classes),
        normalise = True,
        title = title
    )
    plt.show()

graph_predictions(test_model, test_datagen, classes,  "Best Test Model on Test Set")
graph_predictions(test_model, val_datagen, val_classes, "Best Test Model on Val Set")
graph_predictions(val_model, test_datagen, classes,  "Best Val Model on Test Set")
graph_predictions(val_model, val_datagen, val_classes, "Best Val Model on Val Set")
graph_predictions(epoch_model, test_datagen, classes,  "Selected Epoch Model on Test Set")
graph_predictions(epoch_model, val_datagen, val_classes, "Selected Epoch Model on Val Set")
# DONT FORGET TO CHANGE WHICH MODEL YOU'RE LOADING
